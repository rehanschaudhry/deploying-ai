# %% [markdown]
# # Structured Outputs
#
# Structured outputs are useful when model responses are passed as inputs to other components of a system.

# %% [markdown]
# ## OpenAI API Structured Output
#
# Historically, the OpenAI interface offered JSON output. However, using JSON output does not ensure adherence to a schema (data types, for example, may not be enforced). An alternative is to define the output schema using Pydantic.
#
# A useful reference is the entry on [Structured Outputs](https://platform.openai.com/docs/guides/structured-outputs) from the API Documentation.

# %% [markdown]
# [Pydantic](https://docs.pydantic.dev/latest/) is a data validation library for Python. In Pydantic, we define [Models](https://docs.pydantic.dev/latest/concepts/models/) which are classes which inherit from [`BaseModel`](https://docs.pydantic.dev/latest/api/base_model/#pydantic.BaseModel) and define [`Fields`](https://docs.pydantic.dev/latest/api/fields/#pydantic.fields.Field) as annotated attributes.

# %%
# %load_ext dotenv
# %dotenv ../../05_src/.secrets

# %%
from openai import OpenAI
from pydantic import BaseModel
import os

client = OpenAI(default_headers={"x-api-key": os.getenv('API_GATEWAY_KEY')},
    base_url='https://k7uffyg03f.execute-api.us-east-1.amazonaws.com/prod/openai/v1')

class CalendarEvent(BaseModel):
    name: str
    date: str
    participants: list[str]

response = client.responses.parse(
    model="gpt-4o-mini",
    input=[
        {"role": "system", "content": "Extract the event information."},
        {
            "role": "user",
            "content": "Alice and Bob are going to a science fair on Friday.",
        },
    ],
    text_format=CalendarEvent,
)

event = response.output_parsed

# %%
event
# Out:
# CalendarEvent(name='Science Fair', date='Friday', participants=['Alice', 'Bob'])

# %% [markdown]
# ## LangChain and Pydantic
#
# LangChain offers capabilities to structure outputs following a specific schema.
#
# In the example below, we use LangChain to obtain a Joke object with a specific structure given by a Pydantic BaseModel.

# %%
# !pip install langchain
# Out:
# Collecting langchain
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain) (1.3.0)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Downloading langgraph-1.1.9-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain) (2.13.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.7.32)
# Requirement already satisfied: packaging>=23.2.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (0.14.1)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_checkpoint-4.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_prebuilt-1.0.10-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: xxhash>=3.5.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langgraph<1.2.0,>=1.1.5->langchain) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\dsi\deploying-ai-env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in c:\dsi\deploying-ai-env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\dsi\deploying-ai-env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: jsonpointer>=1.9 in c:\dsi\deploying-ai-env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.1.1)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\dsi\deploying-ai-env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\dsi\deploying-ai-env\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (0.25.0)
# Requirement already satisfied: anyio in c:\dsi\deploying-ai-env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (4.13.0)
# Requirement already satisfied: certifi in c:\dsi\deploying-ai-env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\dsi\deploying-ai-env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\dsi\deploying-ai-env\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\dsi\deploying-ai-env\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\dsi\deploying-ai-env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\dsi\deploying-ai-env\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain) (2.6.3)
# Downloading langchain-1.2.15-py3-none-any.whl (112 kB)
# Downloading langgraph-1.1.9-py3-none-any.whl (173 kB)
# Downloading langgraph_checkpoint-4.0.2-py3-none-any.whl (51 kB)
# Downloading langgraph_prebuilt-1.0.10-py3-none-any.whl (36 kB)
# Downloading langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Downloading ormsgpack-1.12.2-cp312-cp312-win_amd64.whl (117 kB)
# Installing collected packages: ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
# Successfully installed langchain-1.2.15 langgraph-1.1.9 langgraph-checkpoint-4.0.2 langgraph-prebuilt-1.0.10 langgraph-sdk-0.3.13 ormsgpack-1.12.2
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install langchain-openai
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.2.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-openai) (1.3.0)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-openai) (2.32.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.7.32)
# Requirement already satisfied: packaging>=23.2.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (26.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (2.13.1)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.14.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\dsi\deploying-ai-env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.13.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\dsi\deploying-ai-env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\dsi\deploying-ai-env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\dsi\deploying-ai-env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.14.0)
# Requirement already satisfied: sniffio in c:\dsi\deploying-ai-env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\dsi\deploying-ai-env\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in c:\dsi\deploying-ai-env\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.4.4)
# Requirement already satisfied: requests>=2.26.0 in c:\dsi\deploying-ai-env\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.33.1)
# Requirement already satisfied: idna>=2.8 in c:\dsi\deploying-ai-env\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain-openai) (3.11)
# Requirement already satisfied: certifi in c:\dsi\deploying-ai-env\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in c:\dsi\deploying-ai-env\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\dsi\deploying-ai-env\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\dsi\deploying-ai-env\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\dsi\deploying-ai-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\dsi\deploying-ai-env\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\dsi\deploying-ai-env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.1 in c:\dsi\deploying-ai-env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai) (2.46.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\dsi\deploying-ai-env\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.3.0->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\dsi\deploying-ai-env\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\dsi\deploying-ai-env\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.6.3)
# Requirement already satisfied: colorama in c:\dsi\deploying-ai-env\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-1.2.0-py3-none-any.whl (98 kB)
# Downloading tiktoken-0.12.0-cp312-cp312-win_amd64.whl (878 kB)
#    ---------------------------------------- 0.0/878.7 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/878.7 kB ? eta -:--:--
#    ---------------------------------------- 878.7/878.7 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: tiktoken, langchain-openai
# Successfully installed langchain-openai-1.2.0 tiktoken-0.12.0
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain.chat_models import init_chat_model

llm = init_chat_model("gpt-4o-mini", 
                      model_provider="openai",
                      base_url='https://k7uffyg03f.execute-api.us-east-1.amazonaws.com/prod/openai/v1',
                      default_headers={"x-api-key": os.getenv('API_GATEWAY_KEY')},
                      )

# %%
from typing import Optional
from pydantic import BaseModel, Field

class Joke(BaseModel):
    setup: str=Field(description="The setup of the joke")
    punchline: str=Field(description="The punchline of the joke")
    rating: Optional[int] = Field(
        default=None, description="How funny the joke is, from 1 to 10"
    )

structured_llm = llm.with_structured_output(Joke)

jk = structured_llm.invoke("Tell me a joke about cats")

# %%
jk
# Out:
# Joke(setup='Why was the cat sitting on the computer?', punchline='Because it wanted to keep an eye on the mouse!', rating=7)

# %% [markdown]
# ## LangChain and TypedDict
#
# We can also use a [typed dictionary or TypedDict](https://typing.python.org/en/latest/spec/typeddict.html) in Python to define the structure of our output. The keyword `Annotated[]` is used to wrap attributes of a typed dictionary.

# %%
from typing import Optional
from typing_extensions import Annotated, TypedDict

class JokeDict(TypedDict):
    setup: Annotated[str, ..., "The setup of the joke"] # No default, with description
    punchline: Annotated[str, ..., "The punchline of the joke"] # No default, with description
    rating: Annotated[Optional[int], None, "How funny the joke is, from 1 to 10"] # Default of None, with description)

# %%
structured_llm_dict = llm.with_structured_output(JokeDict)
jk_dict = structured_llm_dict.invoke("Tell me a joke about dogs")

# %%
jk_dict
# Out:
# {'setup': 'Why did the dog sit in the shade?',
#  'punchline': "Because he didn't want to become a hot dog!",
#  'rating': 7}
